# %%
import pandas as pd

df = pd.read_csv('pill.csv')

df
# Out:
#       entpName                               itemName    itemSeq  \
# 0      동화약품(주)                                    활명수  195700020
# 1      신신제약(주)  신신티눈고(살리실산반창고)(수출명:SINSINCORNPLASTER)  195900034
# 2      삼진제약(주)                                   아네모정  195900043
# 3      동아제약(주)                 타치온정50밀리그램(글루타티온(환원형))  197100015
# 4      동아제약(주)                 타치온정50밀리그램(글루타티온(환원형))  197100015
# ..         ...                                    ...        ...
# 95     삼일제약(주)                          포타딘연고(포비돈요오드)  198000168
# 96  (주)동구바이오제약                     글루100정(글루타티온(환원형))  201305220
# 97     신신제약(주)                           나오덤크림(구아야줄렌)  201309340
# 98       (주)퍼슨                           아줄린연고(구아야줄렌)  201402801
# 99     삼일제약(주)                       포리부틴정(트리메부틴말레산염)  198000170
#
#                                            efcyQesitm  \
# 0   <p>이 약은 식욕감퇴(식욕부진), 위부팽만감, 소화불량, 과식, 체함, 구역, 구...
# 1              <p>이 약은 티눈, 못(굳은살), 사마귀에 사용합니다. </p>\n
# ...

# %%
new_df = df.drop(['itemSeq', 'openDe', 'updateDe', 'itemImage'], axis=1)

# %%
new_df
# Out:
#       entpName                               itemName  \
# 0      동화약품(주)                                    활명수
# 1      신신제약(주)  신신티눈고(살리실산반창고)(수출명:SINSINCORNPLASTER)
# 2      삼진제약(주)                                   아네모정
# 3      동아제약(주)                 타치온정50밀리그램(글루타티온(환원형))
# 4      동아제약(주)                 타치온정50밀리그램(글루타티온(환원형))
# ..         ...                                    ...
# 95     삼일제약(주)                          포타딘연고(포비돈요오드)
# 96  (주)동구바이오제약                     글루100정(글루타티온(환원형))
# 97     신신제약(주)                           나오덤크림(구아야줄렌)
# 98       (주)퍼슨                           아줄린연고(구아야줄렌)
# 99     삼일제약(주)                       포리부틴정(트리메부틴말레산염)
#
#                                            efcyQesitm  \
# 0   <p>이 약은 식욕감퇴(식욕부진), 위부팽만감, 소화불량, 과식, 체함, 구역, 구...
# 1              <p>이 약은 티눈, 못(굳은살), 사마귀에 사용합니다. </p>\n
# 2   <p>이 약은 위산과다, 속쓰림, 위부불쾌감, 위부팽만감, 체함, 구역, 구토, 위...
# 3                      <p>이 약은 약물중독, 자가중독에 사용합니다.</p>
# ...
